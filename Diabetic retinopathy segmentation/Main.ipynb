# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# %cp -av DRsegmentation myDRsegmentation
# Out:
# /content/drive/MyDrive
# 'DRsegmentation' -> 'myDRsegmentation'

# %%
import os
image_path = "/content/drive/MyDrive/data/images/training/"
HEx_mask_path = "/content/drive/MyDrive/data/groundtruths/training/hard exudates/"
HE_mask_path = "/content/drive/MyDrive/data/groundtruths/training/haemorrhages/"
MA_mask_path = "/content/drive/MyDrive/data/groundtruths/training/microaneurysms/"
SEx_mask_path = "/content/drive/MyDrive/data/groundtruths/training/soft exudates/"
images = os.listdir(image_path)
HEx_masks = os.listdir(HEx_mask_path)
HE_masks = os.listdir(HE_mask_path)
MA_masks = os.listdir(MA_mask_path)
SEx_masks = os.listdir(SEx_mask_path)
images.sort()
HEx_masks.sort()
HE_masks.sort()
MA_masks.sort()
SEx_masks.sort()

# %%
# !python drive/MyDrive/DRsegmentation/HEDNet_cGAN/blackmask.py

# %%
# !python drive/MyDrive/DRsegmentation/HEDNet/train.py --seed 765 --preprocess '2' --lesion 'MA'

# %%
# !python drive/MyDrive/DRsegmentation/HEDNet_cGAN/train_gan_ex.py --gan True --seed 765

# %%
# !python drive/MyDrive/DRsegmentation/UNet/train.py --seed 765 --preprocess '2' --lesion 'MA'
# Out:
# Starting epoch 1/5000.
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Starting epoch 2/5000.
#
# Starting epoch 3/5000.
#
# Starting epoch 4/5000.
#
# Starting epoch 5/5000.
#
# Starting epoch 6/5000.
#
# Starting epoch 7/5000.
#
# Starting epoch 8/5000.
#
# Starting epoch 9/5000.
#
# Starting epoch 10/5000.
#
# Starting epoch 11/5000.
#
# Starting epoch 12/5000.
#
# Starting epoch 13/5000.
#
# Starting epoch 14/5000.
#
# Starting epoch 15/5000.
#
# Starting epoch 16/5000.
#
# ...

# %%
pip install ipdb
